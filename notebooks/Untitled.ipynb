# %%
import sys
import cv2
import numpy as np
from matplotlib import pyplot as plt
from scipy.ndimage.filters import convolve

# %%
# Criação da mascara de Gauss
def gaussian_kernel(size, sigma=1):
    size = int(size) // 2
    x, y = np.mgrid[-size:size+1, -size:size+1]
    normal = 1 / (2.0 * np.pi * sigma**2)
    g =  np.exp(-((x**2 + y**2) / (2.0*sigma**2))) * normal
    return g

# %%
img = cv2.imread("images/lena_std.tif")[:,:,::-1]

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.imshow(gray, cmap='gray')
plt.title('Lenna in Gray'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
 gauss_img = convolve(gray, gaussian_kernel(5, 1))

# %%
plt.imshow(gauss_img, cmap='gray')
plt.title('Imagem filtrada'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
plt.subplot(121),plt.imshow(gray,cmap = 'gray')
plt.title('Imagem original'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(gauss_img,cmap = 'gray')
plt.title('Após filtro'), plt.xticks([]), plt.yticks([])
# Out:
# (Text(0.5, 1.0, 'Após filtro'), ([], []), ([], []))

# %%
gaussian_kernel(3,2.8)
# Out:
# array([[0.01786938, 0.01904613, 0.01786938],
#        [0.01904613, 0.02030038, 0.01904613],
#        [0.01786938, 0.01904613, 0.01786938]])

# %%
x = bool(-3)
y = bool("True" * x)
z = bool("False")

print(x and y and z)
# Out:
# True

# %%
# Out:
# True
