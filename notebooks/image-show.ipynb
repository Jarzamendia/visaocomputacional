# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('images/messi.jpg',0) #0 to grayscale

# %matplotlib inline

f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)

plt.imshow(img, cmap = 'gray')
plt.title('My images')
# Out:
# Text(0.5, 1.0, 'My images')
